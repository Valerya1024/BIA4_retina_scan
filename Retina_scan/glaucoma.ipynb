# %%
import scipy.io as scio
import pandas as pd
import matplotlib.pyplot as plt
import h5py
import numpy as np
from skimage.transform import resize
from skimage.exposure import rescale_intensity

label_path = "/content/drive/MyDrive/glaucoma/glaucoma.csv"
img_length = 256
glaucoma_label = pd.read_csv(label_path)
print(glaucoma_label.head())
dataset_annotation = np.zeros((650,img_length,img_length))
dataset_image = np.zeros((650,img_length,img_length,3))
dataset_expCDR = np.zeros(650)
dataset_eye = np.zeros(650, dtype='int8')
dataset_set = np.zeros(650, dtype='int8')
dataset_glaucoma = np.zeros(650, dtype='int8')

directory_annotation = "/content/drive/MyDrive/glaucoma/Semi-automatic-annotations/"
directory_image = "/content/drive/MyDrive/glaucoma/Images/"
for i in range(glaucoma_label.shape[0]):
    n = str(i+1).rjust(3,'0')
    #print(i)
    # annotation
    path=directory_annotation+n+".mat"
    l = scio.loadmat(path)
    img_annotation = l['mask']
    mid = int(img_annotation.shape[1]/2)
    img_annotation = rescale_intensity(img_annotation, in_range=(0, 2), out_range=(0, 255))
    dataset_annotation[i] = resize(img_annotation[:,mid-1024:mid+1024], (img_length,img_length))
    # image
    path=directory_image+n+".jpg"
    img = plt.imread(path)
    dataset_image[i] = resize(img[:,mid-1024:mid+1024,:], (img_length,img_length,3))
    # CDR
    dataset_expCDR[i] = glaucoma_label.loc[i,"ExpCDR"]
    # Eye
    dataset_eye[i] = 0 if glaucoma_label.loc[i,"Eye"] == "OD" else 1
    # Set
    dataset_set[i] = 0 if glaucoma_label.loc[i,"Set"] == "A" else 1
    # Glaucoma
    dataset_glaucoma[i] = glaucoma_label.loc[i,"Glaucoma"]

### augmentation/processing to images here

f = h5py.File("/content/drive/MyDrive/glaucoma/glaucoma.h5","w")
f.create_dataset("image",data = dataset_image)
f.create_dataset("annotation",data = dataset_annotation)
f.create_dataset("expCDR",data = dataset_expCDR)
f.create_dataset("eye",data = dataset_eye)
f.create_dataset("set",data = dataset_set)
f.create_dataset("glaucoma",data = dataset_glaucoma)

f.close()
# Out:
#   Filename  ExpCDR Eye Set  Glaucoma
# 0  001.jpg  0.7097  OD   A         0
# 1  002.jpg  0.6953  OS   A         0
# 2  003.jpg  0.9629  OS   A         0
# 3  004.jpg  0.7246  OD   A         0
# 4  005.jpg  0.6138  OS   A         0

# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt

with h5py.File("/content/drive/MyDrive/glaucoma/glaucoma.h5",'r+') as f:
    
    img_annotations = f["annotation"]
    plt.hist(img_annotations[0].ravel(), bins=255, color="black")
    plt.imshow(img_annotations[0], cmap = "gray")
    l = img_annotations.shape[0]
    #img_length = 512
    mask = np.zeros((l,img_length,img_length,2), dtype=np.bool)
    for i in range(l):
        mask[i,:,:,0] = img_annotations[i] > 100
        mask[i,:,:,1] = img_annotations[i] > 200
        
    plt.imshow(mask[0,:,:,0], cmap = "gray")
    plt.imshow(mask[0,:,:,1], cmap = "gray")
    
    f.create_dataset("mask",data = mask)

# %%
import numpy as np

def split_train_val(percent_train,seed,train):
    l = np.array(range(img_num))
    np.random.seed(seed)
    np.random.shuffle(l)
    train_num = int(img_num * percent_train)
    if train:
        data_id = np.sort(l[:train_num])
    else:
        data_id = np.sort(l[train_num:])
    return data_id

# %%
import matplotlib.pyplot as plt
import numpy as np
import h5py
import random
import tensorflow as tf
import os

from keras.models import Model, load_model
from keras.layers import Input
from keras.layers.core import Dropout, Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K

f = h5py.File("/content/drive/MyDrive/glaucoma/glaucoma.h5",'r')
img_num = 650


train_id = split_train_val(0.8, 0, True)
train_data = f["image"][train_id]
train_mask = f["mask"][train_id]

# %%
val_id = split_train_val(0.8, 0, True)
val_data = f["image"][val_id]
val_mask = f["mask"][val_id]

# %%
'''
# check figure
ix = random.randint(0, len(train_id))
plt.imshow(train_data[ix])
plt.show()
plt.imshow(np.squeeze(train_mask[ix,:,:,0]), cmap="gray")
plt.show()
plt.imshow(np.squeeze(train_mask[ix,:,:,1]), cmap="gray")
plt.show()
'''

# Build a U-net model

img_length = 256
img_channel = 3

inputs = tf.keras.layers.Input((img_length, img_length, img_channel))
s = tf.keras.layers.Lambda(lambda x: x / 255)(inputs) #  normalization

c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (s)
c1 = Dropout(0.1) (c1)
c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c1)
p1 = MaxPooling2D((2, 2)) (c1)

c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p1)
c2 = Dropout(0.1) (c2)
c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c2)
p2 = MaxPooling2D((2, 2)) (c2)

c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p2)
c3 = Dropout(0.2) (c3)
c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c3)
p3 = MaxPooling2D((2, 2)) (c3)

c4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p3)
c4 = Dropout(0.2) (c4)
c4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c4)
p4 = MaxPooling2D(pool_size=(2, 2)) (c4)

c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p4)
c5 = Dropout(0.3) (c5)
c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c5)

u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same') (c5)
u6 = concatenate([u6, c4])
c6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u6)
c6 = Dropout(0.2) (c6)
c6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c6)

u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c6)
u7 = concatenate([u7, c3])
c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u7)
c7 = Dropout(0.2) (c7)
c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c7)

u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c7)
u8 = concatenate([u8, c2])
c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u8)
c8 = Dropout(0.1) (c8)
c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c8)

u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c8)
u9 = concatenate([u9, c1], axis=3)
c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u9)
c9 = Dropout(0.1) (c9)
c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c9)

outputs = Conv2D(2, (1, 1), activation='sigmoid') (c9)
model = Model(inputs=[inputs], outputs=[outputs])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  lambda_1 (Lambda)              (None, 256, 256, 3)  0           ['input_2[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 256, 256, 16  448         ['lambda_1[0][0]']
#                                 )
#
#  dropout_5 (Dropout)            (None, 256, 256, 16  0           ['conv2d_10[0][0]']
#                                 )
#
#  conv2d_11 (Conv2D)             (None, 256, 256, 16  2320        ['dropout_5[0][0]']
#                                 )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 128, 128, 16  0          ['conv2d_11[0][0]']
#                                 )
#
#  conv2d_12 (Conv2D)             (None, 128, 128, 32  4640        ['max_pooling2d_4[0][0]']
#                                 )
#
#  dropout_6 (Dropout)            (None, 128, 128, 32  0           ['conv2d_12[0][0]']
#                                 )
#
#  conv2d_13 (Conv2D)             (None, 128, 128, 32  9248        ['dropout_6[0][0]']
#                                 )
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 64, 64, 32)  0           ['conv2d_13[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 64, 64, 64)   18496       ['max_pooling2d_5[0][0]']
#
#  dropout_7 (Dropout)            (None, 64, 64, 64)   0           ['conv2d_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 64, 64, 64)   36928       ['dropout_7[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 32, 32, 64)  0           ['conv2d_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 32, 32, 128)  73856       ['max_pooling2d_6[0][0]']
#
#  dropout_8 (Dropout)            (None, 32, 32, 128)  0           ['conv2d_16[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 32, 32, 128)  147584      ['dropout_8[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 16, 16, 128)  0          ['conv2d_17[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 16, 16, 256)  295168      ['max_pooling2d_7[0][0]']
#
#  dropout_9 (Dropout)            (None, 16, 16, 256)  0           ['conv2d_18[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 16, 16, 256)  590080      ['dropout_9[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 32, 32, 128)  131200     ['conv2d_19[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 256)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'conv2d_17[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 32, 32, 128)  295040      ['concatenate_1[0][0]']
#
#  dropout_10 (Dropout)           (None, 32, 32, 128)  0           ['conv2d_20[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 32, 32, 128)  147584      ['dropout_10[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 64, 64, 64)  32832       ['conv2d_21[0][0]']
#  spose)
#
#  concatenate_2 (Concatenate)    (None, 64, 64, 128)  0           ['conv2d_transpose_2[0][0]',
#                                                                   'conv2d_15[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 64, 64, 64)   73792       ['concatenate_2[0][0]']
#
#  dropout_11 (Dropout)           (None, 64, 64, 64)   0           ['conv2d_22[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 64, 64, 64)   36928       ['dropout_11[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 128, 128, 32  8224       ['conv2d_23[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 128, 128, 64  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'conv2d_13[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 128, 128, 32  18464       ['concatenate_3[0][0]']
#                                 )
#
#  dropout_12 (Dropout)           (None, 128, 128, 32  0           ['conv2d_24[0][0]']
#                                 )
#
#  conv2d_25 (Conv2D)             (None, 128, 128, 32  9248        ['dropout_12[0][0]']
#                                 )
#
#  conv2d_transpose_4 (Conv2DTran  (None, 256, 256, 16  2064       ['conv2d_25[0][0]']
#  spose)                         )
#
#  concatenate_4 (Concatenate)    (None, 256, 256, 32  0           ['conv2d_transpose_4[0][0]',
#                                 )                                 'conv2d_11[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 256, 256, 16  4624        ['concatenate_4[0][0]']
#                                 )
#
#  dropout_13 (Dropout)           (None, 256, 256, 16  0           ['conv2d_26[0][0]']
#                                 )
#
#  conv2d_27 (Conv2D)             (None, 256, 256, 16  2320        ['dropout_13[0][0]']
#                                 )
#
#  conv2d_28 (Conv2D)             (None, 256, 256, 2)  34          ['conv2d_27[0][0]']
#
# ==================================================================================================
# Total params: 1,941,122
# Trainable params: 1,941,122
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# training
earlystopper = EarlyStopping(patience=5, verbose=1)
checkpointer = ModelCheckpoint('/content/drive/MyDrive/glaucoma/model-glaucoma-1.h5', verbose=1, save_best_only=True)
results = model.fit(train_data, train_mask, validation_data=(val_data,val_mask), batch_size=16, epochs=50, 
                    callbacks=[earlystopper, checkpointer])
# Out:
# Epoch 1/50
# 33/33 [==============================] - ETA: 0s - loss: 0.2164 - accuracy: 0.6968
# Epoch 00001: val_loss improved from inf to 0.10911, saving model to /content/drive/MyDrive/glaucoma/model-glaucoma-1.h5
# 33/33 [==============================] - 25s 565ms/step - loss: 0.2164 - accuracy: 0.6968 - val_loss: 0.1091 - val_accuracy: 0.9445
# Epoch 2/50
# 33/33 [==============================] - ETA: 0s - loss: 0.0947 - accuracy: 0.8109
# Epoch 00002: val_loss improved from 0.10911 to 0.09233, saving model to /content/drive/MyDrive/glaucoma/model-glaucoma-1.h5
# 33/33 [==============================] - 15s 471ms/step - loss: 0.0947 - accuracy: 0.8109 - val_loss: 0.0923 - val_accuracy: 0.9968
# Epoch 3/50
# 33/33 [==============================] - ETA: 0s - loss: 0.0814 - accuracy: 0.8064
# Epoch 00003: val_loss improved from 0.09233 to 0.07060, saving model to /content/drive/MyDrive/glaucoma/model-glaucoma-1.h5
# 33/33 [==============================] - 15s 466ms/step - loss: 0.0814 - accuracy: 0.8064 - val_loss: 0.0706 - val_accuracy: 0.9930
# Epoch 4/50
# 33/33 [==============================] - ETA: 0s - loss: 0.0635 - accuracy: 0.9123
# Epoch 00004: val_loss improved from 0.07060 to 0.04634, saving model to /content/drive/MyDrive/glaucoma/model-glaucoma-1.h5
# 33/33 [==============================] - 15s 467ms/step - loss: 0.0635 - accuracy: 0.9123 - val_loss: 0.0463 - val_accuracy: 0.9970
# Epoch 5/50
# 33/33 [==============================] - ETA: 0s - loss: 0.0309 - accuracy: 0.9393
# Epoch 00005: val_loss improved from 0.04634 to 0.02518, saving model to /content/drive/MyDrive/glaucoma/model-glaucoma-1.h5
# 33/33 [==============================] - 15s 468ms/step - loss: 0.0309 - accuracy: 0.9393 - val_loss: 0.0252 - val_accuracy: 0.9949
# Epoch 6/50
# 33/33 [==============================] - ETA: 0s - loss: 0.0195 - accuracy: 0.9582
# Epoch 00006: val_loss improved from 0.02518 to 0.01585, saving model to /content/drive/MyDrive/glaucoma/model-glaucoma-1.h5
# 33/33 [==============================] - 15s 467ms/step - loss: 0.0195 - accuracy: 0.9582 - val_loss: 0.0159 - val_accuracy: 0.9968
# Epoch 7/50
# 33/33 [==============================] - ETA: 0s - loss: 0.0158 - accuracy: 0.9040
# Epoch 00007: val_loss improved from 0.01585 to 0.01299, saving model to /content/drive/MyDrive/glaucoma/model-glaucoma-1.h5
# 33/33 [==============================] - 15s 470ms/step - loss: 0.0158 - accuracy: 0.9040 - val_loss: 0.0130 - val_accuracy: 0.9905
# Epoch 8/50
# 33/33 [==============================] - ETA: 0s - loss: 0.0146 - accuracy: 0.8566
# Epoch 00008: val_loss improved from 0.01299 to 0.01234, saving model to /content/drive/MyDrive/glaucoma/model-glaucoma-1.h5
# 33/33 [==============================] - 15s 467ms/step - loss: 0.0146 - accuracy: 0.8566 - val_loss: 0.0123 - val_accuracy: 0.9587
# Epoch 9/50
# 33/33 [==============================] - ETA: 0s - loss: 0.0125 - accuracy: 0.8307
# Epoch 00009: val_loss improved from 0.01234 to 0.01074, saving model to /content/drive/MyDrive/glaucoma/model-glaucoma-1.h5
# 33/33 [==============================] - 15s 467ms/step - loss: 0.0125 - accuracy: 0.8307 - val_loss: 0.0107 - val_accuracy: 0.9105
# Epoch 10/50
# 33/33 [==============================] - ETA: 0s - loss: 0.0124 - accuracy: 0.7800
# Epoch 00010: val_loss did not improve from 0.01074
# 33/33 [==============================] - 15s 449ms/step - loss: 0.0124 - accuracy: 0.7800 - val_loss: 0.0111 - val_accuracy: 0.9595
# Epoch 11/50
# 33/33 [==============================] - ETA: 0s - loss: 0.0126 - accuracy: 0.7410
# Epoch 00011: val_loss did not improve from 0.01074
# 33/33 [==============================] - 15s 448ms/step - loss: 0.0126 - accuracy: 0.7410 - val_loss: 0.0113 - val_accuracy: 0.8212
# Epoch 12/50
# 33/33 [==============================] - ETA: 0s - loss: 0.0107 - accuracy: 0.7575
# Epoch 00012: val_loss improved from 0.01074 to 0.01025, saving model to /content/drive/MyDrive/glaucoma/model-glaucoma-1.h5
# 33/33 [==============================] - 15s 470ms/step - loss: 0.0107 - accuracy: 0.7575 - val_loss: 0.0102 - val_accuracy: 0.8115
# Epoch 13/50
# 33/33 [==============================] - ETA: 0s - loss: 0.0098 - accuracy: 0.7003
# Epoch 00013: val_loss did not improve from 0.01025
# 33/33 [==============================] - 15s 448ms/step - loss: 0.0098 - accuracy: 0.7003 - val_loss: 0.0104 - val_accuracy: 0.7569
# Epoch 14/50
# 33/33 [==============================] - ETA: 0s - loss: 0.0097 - accuracy: 0.6863
# Epoch 00014: val_loss improved from 0.01025 to 0.00860, saving model to /content/drive/MyDrive/glaucoma/model-glaucoma-1.h5
# 33/33 [==============================] - 16s 473ms/step - loss: 0.0097 - accuracy: 0.6863 - val_loss: 0.0086 - val_accuracy: 0.8199
# Epoch 15/50
# 33/33 [==============================] - ETA: 0s - loss: 0.0096 - accuracy: 0.6975
# Epoch 00015: val_loss did not improve from 0.00860
# 33/33 [==============================] - 15s 447ms/step - loss: 0.0096 - accuracy: 0.6975 - val_loss: 0.0121 - val_accuracy: 0.7497
# Epoch 16/50
# 33/33 [==============================] - ETA: 0s - loss: 0.0097 - accuracy: 0.6888
# Epoch 00016: val_loss did not improve from 0.00860
# 33/33 [==============================] - 15s 451ms/step - loss: 0.0097 - accuracy: 0.6888 - val_loss: 0.0094 - val_accuracy: 0.7794
# Epoch 17/50
# 33/33 [==============================] - ETA: 0s - loss: 0.0093 - accuracy: 0.7169
# Epoch 00017: val_loss did not improve from 0.00860
# 33/33 [==============================] - 15s 448ms/step - loss: 0.0093 - accuracy: 0.7169 - val_loss: 0.0094 - val_accuracy: 0.8561
# Epoch 18/50
# 33/33 [==============================] - ETA: 0s - loss: 0.0087 - accuracy: 0.7283
# Epoch 00018: val_loss improved from 0.00860 to 0.00769, saving model to /content/drive/MyDrive/glaucoma/model-glaucoma-1.h5
# 33/33 [==============================] - 15s 469ms/step - loss: 0.0087 - accuracy: 0.7283 - val_loss: 0.0077 - val_accuracy: 0.7182
# Epoch 19/50
# 33/33 [==============================] - ETA: 0s - loss: 0.0087 - accuracy: 0.6961
# Epoch 00019: val_loss did not improve from 0.00769
# 33/33 [==============================] - 15s 450ms/step - loss: 0.0087 - accuracy: 0.6961 - val_loss: 0.0087 - val_accuracy: 0.7130
# Epoch 20/50
# 33/33 [==============================] - ETA: 0s - loss: 0.0086 - accuracy: 0.6975
# Epoch 00020: val_loss did not improve from 0.00769
# 33/33 [==============================] - 15s 448ms/step - loss: 0.0086 - accuracy: 0.6975 - val_loss: 0.0094 - val_accuracy: 0.9055
# Epoch 21/50
# 33/33 [==============================] - ETA: 0s - loss: 0.0080 - accuracy: 0.7428
# Epoch 00021: val_loss improved from 0.00769 to 0.00749, saving model to /content/drive/MyDrive/glaucoma/model-glaucoma-1.h5
# 33/33 [==============================] - 15s 471ms/step - loss: 0.0080 - accuracy: 0.7428 - val_loss: 0.0075 - val_accuracy: 0.8725
# Epoch 22/50
# 33/33 [==============================] - ETA: 0s - loss: 0.0082 - accuracy: 0.7081
# Epoch 00022: val_loss improved from 0.00749 to 0.00742, saving model to /content/drive/MyDrive/glaucoma/model-glaucoma-1.h5
# 33/33 [==============================] - 15s 468ms/step - loss: 0.0082 - accuracy: 0.7081 - val_loss: 0.0074 - val_accuracy: 0.8362
# Epoch 23/50
# 33/33 [==============================] - ETA: 0s - loss: 0.0078 - accuracy: 0.6952
# Epoch 00023: val_loss improved from 0.00742 to 0.00728, saving model to /content/drive/MyDrive/glaucoma/model-glaucoma-1.h5
# 33/33 [==============================] - 15s 466ms/step - loss: 0.0078 - accuracy: 0.6952 - val_loss: 0.0073 - val_accuracy: 0.8471
# Epoch 24/50
# 33/33 [==============================] - ETA: 0s - loss: 0.0080 - accuracy: 0.7282
# Epoch 00024: val_loss did not improve from 0.00728
# 33/33 [==============================] - 15s 447ms/step - loss: 0.0080 - accuracy: 0.7282 - val_loss: 0.0095 - val_accuracy: 0.8375
# Epoch 25/50
# 33/33 [==============================] - ETA: 0s - loss: 0.0140 - accuracy: 0.8769
# Epoch 00025: val_loss did not improve from 0.00728
# 33/33 [==============================] - 15s 448ms/step - loss: 0.0140 - accuracy: 0.8769 - val_loss: 0.0090 - val_accuracy: 0.9963
# Epoch 26/50
# 33/33 [==============================] - ETA: 0s - loss: 0.0096 - accuracy: 0.9321
# Epoch 00026: val_loss did not improve from 0.00728
# 33/33 [==============================] - 15s 448ms/step - loss: 0.0096 - accuracy: 0.9321 - val_loss: 0.0093 - val_accuracy: 0.9949
# Epoch 27/50
# 33/33 [==============================] - ETA: 0s - loss: 0.0083 - accuracy: 0.9115
# Epoch 00027: val_loss did not improve from 0.00728
# 33/33 [==============================] - 15s 450ms/step - loss: 0.0083 - accuracy: 0.9115 - val_loss: 0.0118 - val_accuracy: 0.9932
# Epoch 28/50
# 33/33 [==============================] - ETA: 0s - loss: 0.0077 - accuracy: 0.8728
# Epoch 00028: val_loss did not improve from 0.00728
# 33/33 [==============================] - 15s 449ms/step - loss: 0.0077 - accuracy: 0.8728 - val_loss: 0.0105 - val_accuracy: 0.9930
# Epoch 00028: early stopping

# %%
from keras.models import load_model
import h5py

with h5py.File("/content/drive/MyDrive/glaucoma/glaucoma.h5",'r') as f:
  '''
  train_id = split_train_val(0.8, 0, True)
  train_data = f["image"][train_id]
  train_mask = f["mask"][train_id]
  val_id = split_train_val(0.8, 0, False)
  val_data = f["image"][val_id]
  val_mask = f["mask"][val_id]
  val_CDR = f["expCDR"][val_id]
  '''
  val_data = f["image"][:]
  val_mask = f["mask"][:]
  val_CDR = f["expCDR"][:]

model = load_model('/content/drive/MyDrive/glaucoma/model-glaucoma-1.h5')
predict = model.predict(val_data)
#print(predict)

# %%
print(predict.shape)
# Out:
# (650, 256, 256, 2)

# %%
import matplotlib.pyplot as plt

def plot_images(*images):
    images = list(images)
    n = len(images)
    fig, ax = plt.subplots(ncols=n, sharey=True)
    for i, img in enumerate(images):
        ax[i].imshow(img, cmap='gray')
        ax[i].axis('off')
    plt.subplots_adjust(left=0.03, bottom=0.03, right=0.97, top=0.97)
    plt.show()

# %%
import random
i = random.randint(0,649)
i = 24
print(i)
plot_images(predict[i,:,:,0],predict[i,:,:,1])
# Out:
# 24

# %%
plot_images(val_mask[i,:,:,0],val_mask[i,:,:,1])

# %%
plt.imshow(val_data[i])

# %%
predict_img_OD = predict.copy()[i,:,:,0]
predict_img_OC = predict.copy()[i,:,:,1]

# %%
from skimage.feature import blob_log
from skimage.io import imread
from math import sqrt

blobs_OD = blob_log(predict_img_OD, min_sigma=10, max_sigma=15, num_sigma=5, threshold=0.3, overlap=.4)
plt.imshow(predict_img_OD, cmap="gray")
for b in blobs_OD:
  y, x, r = b
  r = r * sqrt(2)
  # Create a circle at the blob center
  c = plt.Circle((x, y), r, color='orange', linewidth=3, fill=False)
  # Draw the circle (gca = "get current axis")
  plt.gca().add_artist(c)
print(blobs_OD)
plt.show()

blobs_OC = blob_log(predict_img_OC, min_sigma=3, max_sigma=10, num_sigma=5, threshold=0.3, overlap=.4)
plt.imshow(predict_img_OC, cmap="gray")
for b in blobs_OC:
  a, b, k = b
  k = k * sqrt(2)
  # Create a circle at the blob center
  c = plt.Circle((b, a), k, color='orange', linewidth=3, fill=False)
  # Draw the circle (gca = "get current axis")
  plt.gca().add_artist(c)
print(blobs_OC)
plt.show()

print(k/r)
print(val_CDR[i])
# Out:
# [[130. 173.  15.]]
# [[129.   173.     8.25]]
# 0.5499999999999999
# 0.5149

# %%
import cv2

ret, predict_img_OD = cv2.threshold(predict_img_OD, 0.5, 1, cv2.THRESH_BINARY)
plt.imshow(predict_img_OD, cmap = "gray")
plt.show()
ret, predict_img_OC = cv2.threshold(predict_img_OC, 0.5, 1, cv2.THRESH_BINARY)
plt.imshow(predict_img_OC, cmap = "gray")
plt.show()

# %%
import numpy as np

VDD = np.sum(predict_img_OD,axis = 1)
VCD = np.sum(predict_img_OC,axis = 1)
VDD = max(VDD)
VCD = max(VCD)
print("VDD:",VDD)
print("VCD:",VCD)
print("CDR:",VCD/VDD)
print("Expected CDR:",val_CDR[i])
# Out:
# VDD: 40.0
# VCD: 24.0
# CDR: 0.6
# Expected CDR: 0.5325
